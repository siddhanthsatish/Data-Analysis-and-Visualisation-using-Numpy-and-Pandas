# %%
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# 'A:\\Summer 2020\\Python Course\\Python for Data Science Course'

# %%
movies = pd.read_csv("P4-Movie-Ratings.csv")

# %%
len(movies)
# Out:
# 559

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns=['Film','Genre','CriticRatings','AudienceRatings','BudgetMillions','Year']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRatings  AudienceRatings  \
# 0  (500) Days of Summer      Comedy             87               81
# 1            10,000 B.C.  Adventure              9               44
# 2             12 Rounds      Action             30               52
# 3              127 Hours  Adventure             93               84
# 4              17 Again      Comedy             55               70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info() #to see what is there in each field
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    object
#  1   Genre            559 non-null    object
#  2   CriticRatings    559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillions   559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe() #to see the data type or the category of the stored data
# Out:
#        CriticRatings  AudienceRatings  BudgetMillions         Year
# count     559.000000       559.000000      559.000000   559.000000
# mean       47.309481        58.744186       50.236136  2009.152057
# std        26.413091        16.826887       48.731817     1.362632
# min         0.000000         0.000000        0.000000  2007.000000
# 25%        25.000000        47.000000       20.000000  2008.000000
# 50%        46.000000        58.000000       35.000000  2009.000000
# 75%        70.000000        72.000000       65.000000  2010.000000
# max        97.000000        96.000000      300.000000  2011.000000

# %%
movies.Film = movies.Film.astype('category') #categories are like factors in R

# %% [markdown]
# movies.describe()

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    object
#  2   CriticRatings    559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillions   559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 47.4+ KB

# %%
movies.Genre = movies.Genre.astype('category')
movies.Film = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   CriticRatings    559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillions   559 non-null    int64
#  5   Year             559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 15.8 KB

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe()
# Out:
#        CriticRatings  AudienceRatings  BudgetMillions
# count     559.000000       559.000000      559.000000
# mean       47.309481        58.744186       50.236136
# std        26.413091        16.826887       48.731817
# min         0.000000         0.000000        0.000000
# 25%        25.000000        47.000000       20.000000
# 50%        46.000000        58.000000       35.000000
# 75%        70.000000        72.000000       65.000000
# max        97.000000        96.000000      300.000000

# %% [markdown]
# #####################################

# %% [markdown]
# ---

# %%
#Joint PLots
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
 join = sns.jointplot(data= movies, x='CriticRatings', y='AudienceRatings', kind='hex',color='Red' )

# %% [markdown]
# ---

# %%
#Historgrams
#Difference between pyplot and seaborn

# %%
m1 = sns.distplot(movies.AudienceRatings, bins=15)

# %%
m2 = sns.distplot(movies.CriticRatings, bins=15)

# %%
sns.set_style("white")
n1 = plt.hist(movies.CriticRatings, bins=15)

# %%
n1 = plt.hist(movies.AudienceRatings, bins=15)

# %% [markdown]
# Inference is that when audience rate the rating recording is more intuitive so the data takes a more normal distribution but when critics rate movies the ratings tend to become more uniformly distributed as they are all giving a close perspective on the movie.

# %% [markdown]
# ---

# %%
#Stacked Histograms

# %%
plt.hist(movies[movies.Genre == "Drama"].BudgetMillions, bins=15)
plt.hist(movies[movies.Genre == "Action"].BudgetMillions, bins=15)
plt.hist(movies[movies.Genre == "Thriller"].BudgetMillions, bins=15)
plt.show()

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
list1= list()
mylabels=list()
for i in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre==i].BudgetMillions)
    mylabels.append(i)
h=plt.hist(list1, bins=30, stacked=True, label=mylabels)

# %% [markdown]
# ---

# %%
#KDE Plots

# %%
vis1 = sns.lmplot(data=movies, x='CriticRatings', y='AudienceRatings', fit_reg=False, hue='Genre', size=7, aspect=1 )

# %%
k1 = sns.kdeplot(movies.CriticRatings, movies.AudienceRatings, shade= True, color='Green', shade_lowest=False)

# %%
k1b=sns.kdeplot(movies.CriticRatings, movies.AudienceRatings, shade= True, cmap='Reds')

# %% [markdown]
# ---

# %%
#Subplots in Python

# %%
#Joint PLots
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
sns.set_style("dark")
k1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRatings)

# %%
k2 = sns.kdeplot(movies.BudgetMillions, movies.CriticRatings)

# %%
f, ax= plt.subplots(3,3) #basically a matrix of charts

# %%
f, ax= plt.subplots(1,2,figsize=(12,6), sharex=True, sharey=True)#fig,ax fig is a chart ax is eitheir a single axes object or an array f figures
k1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRatings, ax=ax[0])
k2 = sns.kdeplot(movies.BudgetMillions, movies.CriticRatings,  ax=ax[1])

# %%
#Violinplots vs Boxplots

# %%
#Violoin Plots

# %%
z=sns.violinplot(data=movies, x='Genre',y='CriticRatings')

# %%
w=sns.boxplot(data=movies, x='Genre',y='CriticRatings')

# %%
w=sns.boxplot(data=movies, x='Genre',y='AudienceRatings')

# %%
w=sns.violinplot(data=movies, x='Genre',y='AudienceRatings')

# %% [markdown]
# ___

# %%
#Creating a Facet Grid

# %%
g=sns.FacetGrid(movies, row='Genre', col= 'Year',hue='Genre')

# %%
g=sns.FacetGrid(movies, row='Genre', col= 'Year',hue='Genre')
g= g.map(plt.scatter, 'CriticRatings', 'AudienceRatings')

# %%
#can populate with any type of chart. Example:histograms

# %%
g=sns.FacetGrid(movies, row='Genre', col= 'Year',hue='Genre')
g= g.map(plt.hist, 'BudgetMillions')

# %%
g=sns.FacetGrid(movies, row='Genre', col= 'Year',hue='Genre')
kws= dict(s=50, linewidth=0.5, edgecolor='black')
g= g.map(plt.scatter, 'CriticRatings', 'AudienceRatings',**kws)
g.set(xlim =(0,100),  ylim=(0,100))
for ax in g.axes.flat:#.flat iterates over a 2D array as though its a list 
    ax.plot((0,100), (0,100), c="gray", ls="--" )
g.add_legend()

# %%
#Building Dashboards

# %%
# We are goping to use subplots function to create dashboards
sns.set_style("darkgrid")
f, axes = plt.subplots(2,2,figsize=(15,15))
k1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRatings, ax=axes[0,0])
k2 = sns.kdeplot(movies.BudgetMillions, movies.CriticRatings,  ax=axes[0,1])
z=sns.violinplot(data=movies, x='Genre',y='CriticRatings' , ax=axes[1,0])
k3 = sns.kdeplot(movies.CriticRatings, movies.AudienceRatings, shade= True, color='Green', shade_lowest=False, ax= axes[1,1])

# %%
f, ax= plt.subplots(1,2,figsize=(12,6), sharex=True, sharey=True)#fig,ax fig is a chart ax is eitheir a single axes object or an array f figures
k1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRatings, ax=ax[0])
k2 = sns.kdeplot(movies.BudgetMillions, movies.CriticRatings,  ax=ax[1])

# %%
z=sns.violinplot(data=movies, x='Genre',y='CriticRatings')

# %%
k3 = sns.kdeplot(movies.CriticRatings, movies.AudienceRatings, shade= True, color='Green', shade_lowest=False)

# %%
# We are goping to use subplots function to create dashboards
sns.set_style("darkgrid")
f, axes = plt.subplots(2,2,figsize=(15,15))
k1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRatings, ax=axes[0,0])
k2 = sns.kdeplot(movies.BudgetMillions, movies.CriticRatings,  ax=axes[0,1])
z=sns.violinplot(data=movies, x='Genre',y='CriticRatings' , ax=axes[1,0])
k3 = sns.kdeplot(movies.CriticRatings, movies.AudienceRatings, shade= True, color='Green', shade_lowest=False, ax= axes[1,1])
k4=sns.kdeplot(movies.CriticRatings, movies.AudienceRatings, shade= True, color='Green', shade_lowest=False, ax= axes[0])

# %%
# We are goping to use subplots function to create dashboards
sns.set_style("darkgrid")
f, axes = plt.subplots(2,2,figsize=(15,15))
k1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRatings, ax=axes[0,0])
k2 = sns.kdeplot(movies.BudgetMillions, movies.CriticRatings,  ax=axes[0,1])
z=sns.violinplot(data=movies, x='Genre',y='CriticRatings' , ax=axes[1,0])
k3 = sns.kdeplot(movies.CriticRatings, movies.AudienceRatings, shade= True, color='Green', shade_lowest=False, ax= axes[1,1])
axes[1,1] = plt.hist(movies.AudienceRatings, bins=15)
